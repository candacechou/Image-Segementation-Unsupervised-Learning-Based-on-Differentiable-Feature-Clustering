# %%
import tensorflow as tf
import cv2
import sys
import numpy as np
import random
from matplotlib import pyplot as plt


import keras
from keras import losses
from keras.models import Sequential,Model
from keras.layers.core import *
from keras.layers import*
from keras.optimizers import *
from keras.utils import to_categorical
from keras import backend as K

from Mynet import MyNet
from losses import loss

# %%
### read the image
img_bgr= cv2.imread("./pytorch-unsupervised-segmentation/PASCAL_VOC_2012/2007_008670.jpg")
img_rgb = img_bgr[:,:,::-1]
plt.imshow(img_rgb)
plt.show()

# %%
### normalize the data
data       = img_rgb.astype('float64')/255.
data       = data.reshape((1,data.shape[0],data.shape[1],data.shape[2]))
Width      = data.shape[1]
Height     = data.shape[2]
### some info about the image
print('Width: ', Width)
print('Height: ',Height)
# Out:
# Width:  500
# Height:  331

# %%
### read the scribble 
mask = cv2.imread("./pytorch-unsupervised-segmentation/PASCAL_VOC_2012/2007_008670_scribble.png",-1)
# mask = mask[:,:,::-1]
plt.imshow(mask)
plt.show()
mask = mask.reshape(-1)
mask_inds = np.unique(mask)
mask_inds = np.delete(mask_inds, np.argwhere(mask_inds==255) )
inds_sim = np.where(mask == 255)[0] 
inds_scr = np.where(mask != 255)[0]
# inds_scr = inds_scr[0:2]
# inds_scr = np
# inds_scr = np.where(mask_rgb == 255)
# print(inds_scr)

# %%
### build a mask
index_scr = np.zeros((Width*Height,1)).astype(np.float64)
index_scr[inds_scr] = 1
print(inds_scr)
# Out:
# [ 25270  25271  25272 ... 146537 146538 146539]

# %%
lr       = 0.1
momentum = 0.9
decay    = 1

nChannel = 100
nCluster = 150
nCov     = 2
mu       = 0.5
v        = 0.25
scribble = True
# print(inds_scr)
# u        = np.zeros((data.shape[0],data.shape[1]))
# print(data.shape)
model = MyNet(Width,Height,nChannel, nCluster,nCov)
sgd = SGD(lr = lr, decay = decay, momentum = momentum, nesterov = True)
model.summary()
model.compile(optimizer= sgd, loss=loss(mu,nCluster,Width,Height,scribble,v,index_scr).losses)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 500, 331, 3)]     0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 500, 331, 100)     2800
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 500, 331, 100)     400
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 500, 331, 100)     90100
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 500, 331, 100)     400
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 500, 331, 150)     15150
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 500, 331, 150)     600
# =================================================================
# Total params: 109,450
# Trainable params: 108,750
# Non-trainable params: 700
# _________________________________________________________________

# %%
num_epoch = 100
# print(data.shape)
model.fit(data, data,epochs = num_epoch)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5411
# Epoch 2/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5409
# Epoch 3/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5407
# Epoch 4/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5406
# Epoch 5/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5405
# Epoch 6/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5403
# Epoch 7/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5402
# Epoch 8/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5400
# Epoch 9/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5399
# Epoch 10/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5396
# Epoch 11/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5395
# Epoch 12/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5394
# Epoch 13/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5393
# Epoch 14/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5391
# Epoch 15/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5391
# Epoch 16/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5389
# Epoch 17/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5388
# Epoch 18/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5387
# Epoch 19/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5386
# Epoch 20/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5386
# Epoch 21/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5386
# Epoch 22/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5382
# Epoch 23/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5381
# Epoch 24/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5379
# Epoch 25/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5378
# Epoch 26/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5377
# Epoch 27/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5375
# Epoch 28/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5374
# Epoch 29/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5372
# Epoch 30/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5371
# Epoch 31/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5370
# Epoch 32/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5367
# Epoch 33/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5366
# Epoch 34/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5364
# Epoch 35/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5361
# Epoch 36/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5360
# Epoch 37/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5359
# Epoch 38/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5357
# Epoch 39/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5357
# Epoch 40/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5356
# Epoch 41/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5354
# Epoch 42/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5353
# Epoch 43/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5352
# Epoch 44/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5351
# Epoch 45/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5349
# Epoch 46/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5348
# Epoch 47/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5346
# Epoch 48/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5345
# Epoch 49/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5344
# Epoch 50/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5343
# Epoch 51/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5342
# Epoch 52/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5340
# Epoch 53/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5339
# Epoch 54/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5338
# Epoch 55/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5338
# Epoch 56/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5336
# Epoch 57/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5334
# Epoch 58/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5332
# Epoch 59/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5331
# Epoch 60/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5331
# Epoch 61/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5330
# Epoch 62/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5328
# Epoch 63/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5326
# Epoch 64/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5325
# Epoch 65/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5324
# Epoch 66/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5322
# Epoch 67/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5324
# Epoch 68/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5322
# Epoch 69/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5321
# Epoch 70/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5322
# Epoch 71/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5321
# Epoch 72/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5319
# Epoch 73/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5317
# Epoch 74/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5316
# Epoch 75/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5315
# Epoch 76/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5314
# Epoch 77/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.5314
# Epoch 78/100
# 1/1 [==============================] - 7s 7s/step - loss: 0.5312
# Epoch 79/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5310
# Epoch 80/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5309
# Epoch 81/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5307
# Epoch 82/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5306
# Epoch 83/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5305
# Epoch 84/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5304
# Epoch 85/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5303
# Epoch 86/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5296
# Epoch 87/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5295
# Epoch 88/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5295
# Epoch 89/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5296
# Epoch 90/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5297
# Epoch 91/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5298
# Epoch 92/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5298
# Epoch 93/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5299
# Epoch 94/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5299
# Epoch 95/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5298
# Epoch 96/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5298
# Epoch 97/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5297
# Epoch 98/100
# 1/1 [==============================] - 4s 4s/step - loss: 0.5297
# Epoch 99/100
# 1/1 [==============================] - 5s 5s/step - loss: 0.5296
# Epoch 100/100
# 1/1 [==============================] - 3s 3s/step - loss: 0.5295

# %%
### clustering
### cool test data

output = model.predict(data)

# %%
### prepare for the colour
label_colours = np.random.randint(255,size=(nCluster,3))

# %%
### plot the data ?
labels = np.argmax(output.reshape((Width*Height,nCluster)),axis = 1)
# print(labels.reshape((Width*Height)))
### image show
im_target_rgb = np.array([label_colours[c] for c in labels])
# print(im_target_rgb.shape)
im_target_rgb = im_target_rgb.reshape((Width,Height,3)).astype(np.uint8)

plt.imshow(im_target_rgb)
plt.show()

# %%
cv2.imwrite( "tiger_mu005_epoch1000.png", im_target_rgb )
# Out:
# True
